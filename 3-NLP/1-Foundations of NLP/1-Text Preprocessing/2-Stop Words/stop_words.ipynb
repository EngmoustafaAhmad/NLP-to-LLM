# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

input_text=" i am moustafa software engineer and  app developer , student at eelu ,passionate self learning. "

words = word_tokenize(input_text)
print(words)

sentences = sent_tokenize(input_text)
print(sentences)

stop_words = set(stopwords.words("english"))

filtered_words = [ i for i in words if i not in stop_words ]
filtered_text=' '.join(filtered_words)

print(filtered_text)
# Out:
# ['i', 'am', 'moustafa', 'software', 'engineer', 'and', 'app', 'developer', ',', 'student', 'at', 'eelu', ',', 'passionate', 'self', 'learning', '.']
# [' i am moustafa software engineer and  app developer , student at eelu ,passionate self learning.']
# moustafa software engineer app developer , student eelu , passionate self learning .
