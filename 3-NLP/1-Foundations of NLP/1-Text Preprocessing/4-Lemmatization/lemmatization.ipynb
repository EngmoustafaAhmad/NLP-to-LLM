# %%
import nltk
nltk.download('wordnet')
from nltk.stem import PorterStemmer,WordNetLemmatizer
from nltk.tokenize import word_tokenize

text = text = """
The striped bats were hanging on their feet and ate best fishes.
He studies studying studied at universities.
The children are running faster than the runners.
Cats are better than dogs.
The leaves on the trees were falling beautifully.
He has gone and is going to go again.
"""



print("================== Stemming ===================")
stemmer = PorterStemmer()
for word in word_tokenize(text):
    stemming_words=stemmer.stem(word)
    print(f"{word} ==> {stemming_words}")
    
print("================= Lemmatization ================")
lemmatizer=WordNetLemmatizer()
for word in word_tokenize(text) :
    lemmatizing_words = lemmatizer.lemmatize(word)
    print(f"{word} ==> {lemmatizing_words}")
# Out:
# ================== Stemming ===================
# The ==> the
# striped ==> stripe
# bats ==> bat
# were ==> were
# hanging ==> hang
# on ==> on
# their ==> their
# feet ==> feet
# and ==> and
# ate ==> ate
# best ==> best
# fishes ==> fish
# . ==> .
# He ==> he
# studies ==> studi
# studying ==> studi
# studied ==> studi
# at ==> at
# universities ==> univers
# . ==> .
# The ==> the
# children ==> children
# are ==> are
# running ==> run
# faster ==> faster
# than ==> than
# the ==> the
# runners ==> runner
# . ==> .
# Cats ==> cat
# are ==> are
# better ==> better
# than ==> than
# dogs ==> dog
# . ==> .
# The ==> the
# leaves ==> leav
# on ==> on
# the ==> the
# trees ==> tree
# were ==> were
# falling ==> fall
# beautifully ==> beauti
# . ==> .
# He ==> he
# has ==> ha
# gone ==> gone
# and ==> and
# is ==> is
# going ==> go
# to ==> to
# go ==> go
# again ==> again
# . ==> .
# ================= Lemmatization ================
# The ==> The
# striped ==> striped
# bats ==> bat
# ...
