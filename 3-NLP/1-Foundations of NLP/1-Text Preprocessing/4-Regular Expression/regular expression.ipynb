# %%
import re

text = """ For customer support, call (02)01012345678 or (02)01123456789.  
Alexandria branch: (02)01287654321  
For urgent inquiries, reach us at (02)01599887766   
01025659925 """

pattern = '\(\d{2}\)\d{11}|\d{11}'

matches= re.findall(pattern,text)

matches
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\('
# <>:8: SyntaxWarning: invalid escape sequence '\('
# C:\Users\AIA\AppData\Local\Temp\ipykernel_14692\2147995565.py:8: SyntaxWarning: invalid escape sequence '\('
#   pattern = '\(\d{2}\)\d{11}|\d{11}'
# ['(02)01012345678',
#  '(02)01123456789',
#  '(02)01287654321',
#  '(02)01599887766',
#  '01025659925']
