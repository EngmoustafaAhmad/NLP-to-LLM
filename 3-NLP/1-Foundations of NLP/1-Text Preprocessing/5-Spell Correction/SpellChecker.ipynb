# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spellchecker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob
text = ' i hav dog plays in gurd ,and i are plays with her'
correct_text = TextBlob(text).correct()
print(correct_text)
# Out:
#  i had dog plays in guard ,and i are plays with her

# %%
from spellchecker import SpellChecker

spell=SpellChecker()
text = [ "informtion","gradution"]

for word in text :
    correct_text= spell.correction(text)
    print(correct_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from spellchecker import SpellChecker
#       3 spell=SpellChecker()
#       4 text = [ "informtion","gradution"]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\spellchecker\__init__.py:2
#       1 # -*- coding: utf-8 -*-
# ----> 2 from  spellchecker.core import Spellchecker,getInstance
#
# File ~\AppData\Roaming\Python\Python313\site-packages\spellchecker\core.py:26
#      23 import inexactsearch
#      24 import urllib
# ---> 26 from indexer import DictionaryIndex
#      27 from langdetect import _detect_lang
#      29 __all__ = ['Spellchecker', 'getInstance']
#
# ModuleNotFoundError: No module named 'indexer'
