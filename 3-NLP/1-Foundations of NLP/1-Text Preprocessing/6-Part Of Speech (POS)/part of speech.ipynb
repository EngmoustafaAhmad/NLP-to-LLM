# %%
import spacy

# %%
import sys
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.5 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.3/12.8 MB 1.5 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.6/12.8 MB 1.5 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.5 MB/s eta 0:00:08
#      ------- -------------------------------- 2.4/12.8 MB 1.5 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/12.8 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.8 MB 1.5 MB/s eta 0:00:07
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("i was happy in the past")

for word in doc:
    print(word.text, word.pos_, spacy.explain(word.pos_),word.tag,spacy.explain(word.tag))
# Out:
# i PRON pronoun 13656873538139661788 None
# was AUX auxiliary 17109001835818727656 None
# happy ADJ adjective 10554686591937588953 None
# in ADP adposition 1292078113972184607 None
# the DET determiner 15267657372422890137 None
# past NOUN noun 15308085513773655218 None
